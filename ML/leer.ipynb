# %% [markdown]
# ####  Realizar la carga de datos desde Python (Google Colab) o R-studio.

# %%
#importo la libreria y le pongo el alias de "pd"
import pandas as pd

# Creo una lista que contiene el nombre de las columnas de la base de datos
COLUMNS = ["age","workclass","fnlwgt","education","education_num","marital","occupation",
           "relationship","race","sex","capital_gain","capital_loss","hours_week","native_country","label"]
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"

#creo un try except por si falla la lectura de la base de datos, no se pare el programa
try:
#Leo la base de datos desde la url
    data_set = pd.read_csv(url,names=COLUMNS)
except:
    print("No se encontro el URL")

#Imprimo una muestra de la base de datos desde arriba(head) y desde abajo(tail)

print(data_set.head())
print(data_set.tail())

#Imprimo la cantidad de filas y columnas que tiene la base de datos
print("Data set con {} Filas y {} Columnas".format(data_set.shape[0],data_set.shape[1]))

#Imprimo nformación general de la base de datos
data_set.info()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#                marital          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_week  native_country   label
# 0          2174             0          40   United-States   <=50K
# ...

# %% [markdown]
# ####   Análisis descriptivo de los datos que incluya las medidas de tendencia central.
# Se Analiza el data set. Identificando, de acuerdo a las columnas, es un dataset que describe individuos con variables como edad, nivel educativo, estado civil. etc
# 1) describe
# 2) describe all, para las columnas que no se analizaba con el describe
# 3) Se agruparon los valores de cada columna, para ver los registros que más y que menos se repiten
# 4) Se analizó las medidas de tendencia centrla

# %%
data_set.describe()
# Como no me describe todos los campos, fuerzo al describe a que describa todos los campos
data_set.describe(include='all')
# Ciclo qe recorre cada columna, agrupa los distintos valores y muestra los que más se repiten hasta los que menos se repiten
for columna in data_set.columns:
    resultado = data_set.groupby(columna).size().reset_index(name='registros')
    resultado = resultado.sort_values(by='registros', ascending=False,ignore_index=True)
    print("*"*30)
    print(columna)
    print("*"*30)
    print(resultado)

#Codigo que recorre cada columna y obtiene 
    #1) media
    #2) mediana
    #3) Desviación estandar
    #4) Moda
for columna in data_set.columns:
    try:
        print("*"*30)
        print(columna)
        print("*"*30)
        print("La media de {} es = {}".format(columna, data_set[columna].mean()))
        print("La mediana de {} es = {}".format(columna, data_set[columna].median()))
        print("La Desviacion estandar de {} es = {}".format(columna, data_set[columna].std()))
        print("Las modas de {} son  = ".format(columna),end="")
        modas =[]
        for moda in data_set[columna].mode():    
            modas.append(moda)   
        print(modas)    
    except:
        print("No se pudo obtener la medida de tendencia central para la columna "+ columna)
    finally:
        print("\n"*2)
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#                     marital       occupation relationship    race    sex  \
# ...

# %%
for columna in data_set.columns:
    resultado = data_set.groupby(columna).size().reset_index(name='registros')
    resultado = resultado.sort_values(by='registros', ascending=False,ignore_index=True)
    print("*"*30)
    print(columna)
    print("*"*30)
    print(resultado)
# Out:
# ********************
# age
# ********************
#     age  registros
# 0    36        898
# 1    31        888
# 2    34        886
# 3    23        877
# 4    35        876
# ..  ...        ...
# 68   83          6
# 69   85          3
# 70   88          3
# 71   86          1
# 72   87          1
#
# [73 rows x 2 columns]
# ********************
# workclass
# ********************
#            workclass  registros
# 0            Private      22696
# 1   Self-emp-not-inc       2541
# 2          Local-gov       2093
# 3                  ?       1836
# 4          State-gov       1298
# 5       Self-emp-inc       1116
# 6        Federal-gov        960
# 7        Without-pay         14
# 8       Never-worked          7
# ********************
# fnlwgt
# ********************
#         fnlwgt  registros
# 0       164190         13
# 1       203488         13
# 2       123011         13
# 3       113364         12
# 4       121124         12
# ...        ...        ...
# ...

# %%
for columna in data_set.columns:
    try:
        print("*"*30)
        print(columna)
        print("*"*30)
        print("La media de {} es = {}".format(columna, data_set[columna].mean()))
        print("La mediana de {} es = {}".format(columna, data_set[columna].median()))
        print("La Desviacion estandar de {} es = {}".format(columna, data_set[columna].std()))
        print("Las modas de {} son  = ".format(columna),end="")
        modas =[]
        for moda in data_set[columna].mode():    
            modas.append(moda)   
        print(modas)    
    except:
        print("No se pudo obtener la medida de tendencia central para la columna "+ columna)
    finally:
        print("\n"*2)
# Out:
# ******************************
# age
# ******************************
# La media de age es = 38.58164675532078
# La mediana de age es = 37.0
# La Desviacion estandar de age es = 13.640432553581146
# Las modas de age son  = [36]
#
#
#
# ******************************
# workclass
# ******************************
# No se pudo obtener la medida de tendencia central para la columna workclass
#
#
#
# ******************************
# fnlwgt
# ******************************
# La media de fnlwgt es = 189778.36651208502
# La mediana de fnlwgt es = 178356.0
# La Desviacion estandar de fnlwgt es = 105549.97769702233
# Las modas de fnlwgt son  = [123011, 164190, 203488]
#
#
#
# ******************************
# education
# ******************************
# No se pudo obtener la medida de tendencia central para la columna education
#
#
#
# ******************************
# education_num
# ******************************
# La media de education_num es = 10.0806793403151
# ...

# %% [markdown]
# #### Tratamiento de missing.

# %%
# Del data set suma todos los nulos por columna
data_set.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital           0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_week        0
# native_country    0
# label             0
# dtype: int64

# %% [markdown]
# #### Identificación y eliminación de errores.

# %%
# No hay ningun valor en nulo. Sin embargo, existe un caracter raro " ? " analizaremos los registros con estos valores,
# este caracter tiene espacios en blanco por lo cual se le elimina espacio en blanco con el metodo strip

#Nuevo data_set con el valor de occupation filtrado 
data_set_2 = data_set[data_set['occupation'].str.strip()!= "?"]
for columna in data_set_2.columns:
    resultado = data_set_2.groupby(columna).size().reset_index(name='registros')
    resultado = resultado.sort_values(by='registros', ascending=False,ignore_index=True)
    print("*"*30)
    print(columna)
    print("*"*30)
    print(resultado)
# Out:
# ******************************
# age
# ******************************
#     age  registros
# 0    36        875
# 1    31        869
# 2    34        860
# 3    37        849
# 4    33        849
# ..  ...        ...
# 67   82          7
# 68   83          5
# 69   85          3
# 70   88          3
# 71   86          1
#
# [72 rows x 2 columns]
# ******************************
# workclass
# ******************************
#            workclass  registros
# 0            Private      22696
# 1   Self-emp-not-inc       2541
# 2          Local-gov       2093
# 3          State-gov       1298
# 4       Self-emp-inc       1116
# 5        Federal-gov        960
# 6        Without-pay         14
# ******************************
# fnlwgt
# ******************************
#         fnlwgt  registros
# 0       203488         13
# 1       164190         13
# 2       113364         12
# 3       148995         12
# 4       123011         12
# ...        ...        ...
# 20490   158962          1
# ...

# %% [markdown]
# #### Datos duplicados.

# %%
#Cantidad de registros Original
print(data_set.shape)


#Cantidad de registros antes de eliminar duplicados pero luego de filtrar los "?" 
print(data_set_2.shape)

#Cantidad de registros luego de eliminar duplicados y luego de filtrar los "?" 
data_set_3 = data_set_2.drop_duplicates()
print(data_set_3.shape)
# Out:
# (32561, 15)
# (30718, 15)
# (30694, 15)
